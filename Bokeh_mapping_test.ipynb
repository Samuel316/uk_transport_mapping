# %%
import json

from pathlib import Path

from bokeh.io import output_file, show
from bokeh.models import GeoJSONDataSource, Line

from bokeh.plotting import figure
from bokeh.tile_providers import OSM, get_provider

path = Path("Data/Border_railway.geojson")
assert path.is_file()

with path.open() as f:
    data = json.load(f)

source = GeoJSONDataSource(geojson=json.dumps(data))

p = figure(background_fill_color="lightgrey", tooltips=TOOLTIPS, x_axis_type="mercator", y_axis_type="mercator")

tile_provider = get_provider(OSM)
# p = figure(x_range=(-2000000, 6000000), y_range=(-1000000, 7000000),
#            x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(tile_provider)

p.line(source=source, line_color="#f46d43", line_width=6)

show(p)

# %%
source
# Out:
# GeoJSONDataSource(id='3284', ...)
